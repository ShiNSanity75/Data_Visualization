# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

batter_2018 = pd.read_csv('batter_2018.csv',encoding='cp950')
#batter_2018 =open('batter_2018.csv')
#<_io.TextIOWrapper name='batter_2018.csv' mode='r' encoding='cp950'>編碼為encoding='cp950'

batter_Lamigo = pd.read_csv('batter_Lamigo.csv',encoding='cp950')
batter_Brothers = pd.read_csv('batter_Brothers.csv',encoding='cp950')
batter_Lions = pd.read_csv('batter_Lions.csv',encoding='cp950')

pitcher_2018 = pd.read_csv('pitcher_2018.csv',encoding='cp950')
pitcher_Lamigo = pd.read_csv('pitcher_Lamigo.csv',encoding='cp950')
pitcher_Brothers = pd.read_csv('pitcher_Brothers.csv',encoding='cp950')
pitcher_Lions = pd.read_csv('pitcher_Lions.csv',encoding='cp950')

batter_2018
#用pandas直接抓
#url = 'http://www.cpbl.com.tw/web/team_playergrade.php?&team=B04&gameno=01'
#table = pd.read_html(url)[0]
#table
# Out:
#    NAME TEAM    G   PA   AB  RBI   R    H   1B  2B   ...     BB  IBB  HBP  CS  \
# 0   張正偉   富邦   99  399  350   31  54  103   81  19   ...     41    0    5   4
# 1   林益全   富邦   95  388  349   54  45  110   76  26   ...     27    3    2   1
# 2   林宥穎   富邦   77  215  189   23  19   49   40   8   ...     14    0    0   3
# 3   于孟馗   富邦   77  214  182   18  23   50   41   8   ...     14    1    2   3
# 4   陳凱倫   富邦   71  151  129   17  29   33   26   4   ...     11    0    2   3
# 5   范國宸   富邦   66  210  195   19  28   56   44   8   ...      8    0    3   1
# 6   李宗賢   富邦   66  127  111   10  17   27   23   4   ...     10    0    1   0
# 7   高國輝   富邦   62  243  198   38  24   50   29  12   ...     40    0    2   1
# 8   方克偉   富邦   61  150  131   12  10   21   18   1   ...     13    0    1   1
# 9   高國麟   富邦   56  156  132   18  24   34   22   6   ...     15    0    5   0
# 10  高孝儀   富邦   53  152  134   19  20   34   26   6   ...      6    0    3   0
# 11  申皓瑋   富邦   45  152  139   18  27   40   28   7   ...     11    1    1   2
# 12  王正棠   富邦   32  142  122   16  28   43   34   6   ...     12    0    1   3
# 13  蔡友達   富邦   24   76   70    5   6   19   12   7   ...      0    0    0   0
# 14  林威廷   富邦   18   31   30    0   4    7    6   1   ...      1    0    0   1
# 15  吳宗峻   富邦   18   33   28    1   5    6    5   1   ...      2    1    1   0
# 16  石翔宇   富邦   14   25   19    2   1    4    4   0   ...      3    0    1   1
# 17  陳品捷   富邦  112  485  415   46  75  122   91  19   ...     48    3    1   5
# 18  蔣智賢   富邦  110  467  429   89  63  142   88  34   ...     27    3    2   1
# 19  林哲瑄   富邦  106  441  388   59  57  108   74  21   ...     31    2   10   4
# 20  胡金龍   富邦  100  422  385   80  68  144  103  26   ...     25    3    1   4
# 21  張瑞麟   富邦    9   17   16    2   3    5    4   0   ...      1    0    0   0
# 22  林旺衛   富邦    8   10    9    0   0    0    0   0   ...      0    1    0   0
# 23  張建銘   富邦    8   16   13    0   0    1    1   0   ...      1    0    2   0
# 24  林瑋恩   富邦    7   24   20    2   2    6    5   1   ...      2    0    0   0
# 25  林志洋   富邦    2    5    5    1   2    2    2   0   ...      0    0    0   0
# 26  陳勤宗   富邦    2    3    3    0   0    1    1   0   ...      0    0    0   0
#
#      GO   AO    G/F    SB%     TA      SSA
# 0   114   80  1.425  0.750  0.734   619.29
# 1    98   91  1.077  0.667  0.782   905.19
# 2    59   50  1.180  0.625  0.523   454.26
# 3    63   38  1.658  0.571  0.594   445.73
# 4    38   30  1.267  0.400  0.600   425.81
# 5    60   43  1.395  0.667  0.604   496.18
# 6    32   28  1.143  1.000  0.598   324.24
# 7    33   66  0.500  0.750  0.854   711.53
# 8    51   33  1.545  0.500  0.377   288.31
# 9    22   36  0.611  1.000  0.770   483.58
# 10   45   37  1.216  1.000  0.551   434.73
# 11   25   31  0.806  0.333  0.721   518.77
# 12   39   21  1.857  0.400  0.833   487.46
# 13   10   16  0.625  1.000  0.500   322.43
# 14   15    4  3.750  0.500  0.370   241.33
# 15    6    4  1.500  0.000  0.500   226.29
# 16    4    3  1.333  0.000  0.500   224.53
# 17  103  115  0.896  0.667  0.766   814.98
# 18  116  102  1.137  0.667  0.896  1370.00
# 19   91  126  0.722  0.818  0.764   938.35
# 20  113   91  1.242  0.636  0.988  1268.03
# 21    5    2  2.500  0.000  0.818   350.50
# 22    2    2  1.000  1.000  0.222     0.00
# 23    2    4  0.500  0.000  0.333    77.92
# 24    4    5  0.800  0.000  0.643   317.00
# 25    3    0  0.000  0.000  0.667   407.00
# 26    2    0  0.000  0.000  0.500   334.33
#
# [27 rows x 31 columns]

# %%
#這段在取出打數大於100的選手之打擊率擊上壘率(全年度)

#batter_2018.sort_values(by=['PA'],ascending=False)#以打數由大到小進行排序
#batter_2018[['NAME','PA']]
batter_2018_PA = batter_2018.loc[(batter_2018['PA'] > 100) , ['NAME','PA','AVG','OBP']]
batter_2018_PA = batter_2018_PA.reset_index(drop=True)
batter_2018_PA
# Out:
#    NAME   PA    AVG    OBP
# 0   張正偉  399  0.294  0.374
# 1   林益全  388  0.315  0.366
# 2   林宥穎  215  0.259  0.304
# 3   于孟馗  214  0.275  0.330
# 4   陳凱倫  151  0.256  0.322
# 5   范國宸  210  0.287  0.321
# 6   李宗賢  127  0.243  0.306
# 7   高國輝  243  0.253  0.379
# 8   方克偉  150  0.160  0.238
# 9   高國麟  156  0.258  0.351
# 10  高孝儀  152  0.254  0.297
# 11  申皓瑋  152  0.288  0.349
# 12  王正棠  142  0.352  0.412
# 13  陳品捷  485  0.294  0.368
# 14  蔣智賢  467  0.331  0.373
# 15  林哲瑄  441  0.278  0.345
# 16  胡金龍  422  0.374  0.414

# %%
#分別取出打數大於100的選手之打擊率擊上壘率(對桃猿、兄弟、統一)
batter_Lamigo_PA = batter_Lamigo.loc[(batter_2018['PA'] > 100) , ['NAME','PA','AVG','OBP']]
batter_Lamigo_PA.rename(columns={"PA": "PA_Lamigo","AVG":"AVG_Lamigo","OBP":"OBP_Lamigo"}, inplace = True)
batter_Lamigo_PA = batter_Lamigo_PA.reset_index(drop=True)

batter_Brothers_PA = batter_Brothers.loc[(batter_2018['PA'] > 100) , ['NAME','PA','AVG','OBP']]
batter_Brothers_PA.rename(columns={"PA": "PA_Brothers","AVG":"AVG_Brothers","OBP":"OBP_Brothers"}, inplace = True)
batter_Brothers_PA = batter_Brothers_PA.reset_index(drop=True)

batter_Lions_PA = batter_Lions.loc[(batter_2018['PA'] > 100) , ['NAME','PA','AVG','OBP']]
batter_Lions_PA.rename(columns={"PA": "PA_Lions","AVG":"AVG_Lions","OBP":"OBP_Lions"}, inplace = True)
batter_Lions_PA = batter_Lions_PA.reset_index(drop=True)
batter_Lions_PA
# Out:
#    NAME  PA_Lions  AVG_Lions  OBP_Lions
# 0   張正偉       134      0.308      0.373
# 1   林益全       131      0.350      0.397
# 2   林宥穎        70      0.226      0.286
# 3   于孟馗        78      0.261      0.293
# 4   陳凱倫        39      0.226      0.333
# 5   范國宸        82      0.354      0.341
# 6   李宗賢        58      0.280      0.351
# 7   高國輝        87      0.243      0.379
# 8   方克偉        52      0.152      0.220
# 9   高國麟        44      0.132      0.227
# 10  高孝儀        35      0.161      0.235
# 11  申皓瑋        57      0.264      0.316
# 12  王正棠        44      0.324      0.439
# 13  陳品捷       145      0.298      0.382
# 14  蔣智賢       164      0.329      0.354
# 15  林哲瑄       139      0.236      0.312
# 16  胡金龍       134      0.317      0.356

# %%
#合併四張表格並且以全年打數排序
batter_inner = pd.merge(batter_2018_PA, batter_Lamigo_PA, how='inner')
batter_inner = pd.merge(batter_inner, batter_Brothers_PA, how='inner')
batter_inner = pd.merge(batter_inner, batter_Lions_PA, how='inner')
batter_inner = batter_inner.sort_values(by=['PA'],ascending=False)
batter_inner = batter_inner.reset_index(drop=True)
batter_inner
# Out:
#    NAME   PA    AVG    OBP  PA_Lamigo  AVG_Lamigo  OBP_Lamigo  PA_Brothers  \
# 0   陳品捷  485  0.294  0.368        170       0.280       0.352          170
# 1   蔣智賢  467  0.331  0.373        158       0.342       0.367          145
# 2   林哲瑄  441  0.278  0.345        148       0.271       0.331          154
# 3   胡金龍  422  0.374  0.414        143       0.458       0.496          145
# 4   張正偉  399  0.294  0.374        126       0.315       0.400          139
# 5   林益全  388  0.315  0.366        121       0.287       0.331          136
# 6   高國輝  243  0.253  0.379         86       0.203       0.349           70
# 7   林宥穎  215  0.259  0.304         67       0.305       0.354           78
# 8   于孟馗  214  0.275  0.330         64       0.231       0.328           72
# 9   范國宸  210  0.287  0.321         67       0.169       0.269           61
# 10  高國麟  156  0.258  0.351         50       0.357       0.449           62
# 11  高孝儀  152  0.254  0.297         69       0.288       0.317           48
# 12  申皓瑋  152  0.288  0.349         47       0.302       0.362           48
# 13  陳凱倫  151  0.256  0.322         57       0.300       0.352           55
# 14  方克偉  150  0.160  0.238         50       0.182       0.240           48
# 15  王正棠  142  0.352  0.412         50       0.378       0.420           48
# 16  李宗賢  127  0.243  0.306         35       0.242       0.286           34
#
#     AVG_Brothers  OBP_Brothers  PA_Lions  AVG_Lions  OBP_Lions
# 0          0.304         0.371       145      0.298      0.382
# 1          0.320         0.400       164      0.329      0.354
# 2          0.326         0.388       139      0.236      0.312
# 3          0.344         0.386       134      0.317      0.356
# 4          0.262         0.353       134      0.308      0.373
# 5          0.306         0.368       131      0.350      0.397
# 6          0.322         0.414        87      0.243      0.379
# 7          0.250         0.278        70      0.226      0.286
# 8          0.328         0.373        78      0.261      0.293
# 9          0.316         0.350        82      0.354      0.341
# 10         0.269         0.361        44      0.132      0.227
# 11         0.273         0.312        35      0.161      0.235
# 12         0.302         0.375        57      0.264      0.316
# 13         0.229         0.283        39      0.226      0.333
# 14         0.146         0.255        52      0.152      0.220
# 15         0.349         0.378        44      0.324      0.439
# 16         0.179         0.250        58      0.280      0.351

# %%
fig = plt.figure(figsize=(25,10))
ax1 = fig.add_subplot(111)

for (i, row) in batter_inner.iterrows():
    plt.bar([i - 0.3, i - 0.1, i + 0.1, i + 0.3], [row['AVG'], row['AVG_Lamigo'], row['AVG_Brothers'], row['AVG_Lions']],
            color=['#888888', '#008AB8', '#FFD700', '#FF8C00'], width=0.2, align='center', edgecolor='#000000')
    
#plt.bar(label=['全年度', 'Lamigo桃猿', '中信兄弟', '統一7-ELEVEn獅'])
#plt.legend()
plt.xticks(range(0, 17), batter_inner['NAME'], fontsize=23)

#for x,y in enumerate(batter_inner['AVG']):
   #plt.text(x, y, '%1.3f' % y, ha='center', va= 'bottom',fontsize=11)

plt.title("富邦悍將球員打擊率比較", fontsize=23)
plt.xlabel('NAME')
plt.ylabel('AVG')
# Out:
# Text(0,0.5,'AVG')

# %%
fig = plt.figure(figsize=(25,10))
ax1 = fig.add_subplot(111)

for (i, row) in batter_inner.iterrows():
    plt.bar([i - 0.3, i - 0.1, i + 0.1, i + 0.3], [row['OBP'], row['OBP_Lamigo'], row['OBP_Brothers'], row['OBP_Lions']],
            color=['#888888', '#008AB8', '#FFD700', '#FF8C00'], width=0.2, align='center', edgecolor='#000000')

plt.xticks(range(0, 17), batter_inner['NAME'], fontsize=23)

#for x,y in enumerate(batter_inner['AVG']):
   #plt.text(x, y, '%1.3f' % y, ha='center', va= 'bottom',fontsize=11)


plt.xlabel('NAME')
plt.ylabel('OBP')
# Out:
# Text(0,0.5,'OBP')

# %%
#取出所有投球局數大於15局之選手的自責分率及每局被上壘率(全年度)
pitcher_2018_IP = pitcher_2018.loc[(pitcher_2018['IP'] > 15) , ['NAME','IP','ERA','WHIP']]
#pitcher_2018_IP = pitcher_2018_IP.sort_values(by=['IP'],ascending=False)
pitcher_2018_IP = pitcher_2018_IP.reset_index(drop=True)
#pitcher_2018_IP.loc[(pitcher_2018_IP['NAME'] == '伍鐸')]
pitcher_2018_IP
# Out:
#    NAME     IP   ERA  WHIP
# 0   賴鴻誠   56.0  3.54  1.34
# 1   倪福德   42.0  3.00  1.10
# 2   張耿豪   36.1  5.20  1.65
# 3   林晨樺   43.0  5.86  1.26
# 4   郭泓志   34.0  3.71  1.32
# 5    伍鐸  169.0  3.25  1.21
# 6    羅力  161.0  3.47  1.20
# 7   陳鴻文   50.2  4.62  1.60
# 8   林煜清   41.0  5.27  1.68
# 9   羅嘉仁   18.1  8.35  2.18
# 10  林羿豪   20.0  4.05  1.15
# 11  黃亦志   76.1  5.66  1.73
# 12  布魯斯  102.1  5.72  1.62
# 13  蔡明晉   26.0  6.92  1.81
# 14  陳仕朋   27.1  7.24  1.79
# 15   喬登   37.2  5.97  1.65
# 16  吳世豪   22.0  1.64  1.14
# 17  林政賢   16.1  6.61  2.02

# %%
#分別取出投球局數大於15局之選手的自責分率及每局被上壘率(對桃猿、兄弟、統一)
pitcher_Lamigo_IP = pitcher_Lamigo.loc[(pitcher_2018['IP'] > 15) , ['NAME','IP','ERA','WHIP']]
pitcher_Lamigo_IP.rename(columns={"IP": "IP_Lamigo","ERA":"ERA_Lamigo","WHIP":"WHIP_Lamigo"}, inplace = True)
pitcher_Lamigo_IP = pitcher_Lamigo_IP.reset_index(drop=True)

pitcher_Brothers_IP = pitcher_Brothers.loc[(pitcher_2018['IP'] > 15) , ['NAME','IP','ERA','WHIP']]
pitcher_Brothers_IP.rename(columns={"IP": "IP_Brothers","ERA":"ERA_Brothers","WHIP":"WHIP_Brothers"}, inplace = True)
pitcher_Brothers_IP = pitcher_Brothers_IP.reset_index(drop=True)

pitcher_Lions_IP = pitcher_Lions.loc[(pitcher_2018['IP'] > 15) , ['NAME','IP','ERA','WHIP']]
pitcher_Lions_IP.rename(columns={"IP": "IP_Lions","ERA":"ERA_Lions","WHIP":"WHIP_Lions"}, inplace = True)
pitcher_Lions_IP = pitcher_Lions_IP.reset_index(drop=True)

pitcher_Lions_IP
# Out:
#    NAME  IP_Lions  ERA_Lions  WHIP_Lions
# 0   賴鴻誠      19.1       3.26        1.40
# 1   倪福德      15.1       1.76        0.91
# 2   張耿豪      12.1       8.03        2.19
# 3   林晨樺      17.1       6.23        1.15
# 4   郭泓志      11.1       6.35        1.76
# 5    伍鐸      47.2       4.34        1.39
# 6    羅力      68.1       3.95        1.11
# 7   陳鴻文      12.2       8.53        2.45
# 8   林煜清      13.1       9.45        2.33
# 9   羅嘉仁       3.1      13.50        2.70
# 10  林羿豪       8.1       1.08        0.72
# 11  黃亦志      29.2       4.55        1.62
# 12  布魯斯      28.2       5.97        1.60
# 13  蔡明晉      12.2       2.84        1.18
# 14  陳仕朋       7.0       7.71        1.86
# 15   喬登       9.2       9.31        2.07
# 16  吳世豪       0.0       0.00        0.00
# 17  林政賢      10.1       5.23        2.03

# %%
#合併四張表格並且以全年投球局數排序
pitcher_inner = pd.merge(pitcher_2018_IP, pitcher_Lamigo_IP, how='inner')
pitcher_inner = pd.merge(pitcher_inner, pitcher_Brothers_IP, how='inner')
pitcher_inner = pd.merge(pitcher_inner, pitcher_Lions_IP, how='inner')
pitcher_inner = pitcher_inner.sort_values(by=['IP'],ascending=False)
pitcher_inner = pitcher_inner.reset_index(drop=True)
pitcher_inner
# Out:
#    NAME     IP   ERA  WHIP  IP_Lamigo  ERA_Lamigo  WHIP_Lamigo  IP_Brothers  \
# 0    伍鐸  169.0  3.25  1.21       42.1        3.83         1.49         79.0
# 1    羅力  161.0  3.47  1.20       61.1        3.52         1.24         31.1
# 2   布魯斯  102.1  5.72  1.62       30.1        6.53         1.78         43.1
# 3   黃亦志   76.1  5.66  1.73       29.0        6.83         1.97         17.2
# 4   賴鴻誠   56.0  3.54  1.34       18.2        5.30         1.39         18.0
# 5   陳鴻文   50.2  4.62  1.60       14.2        3.07         1.57         23.1
# 6   林晨樺   43.0  5.86  1.26       15.2        5.17         0.96         10.0
# 7   倪福德   42.0  3.00  1.10       13.1        3.38         1.12         13.1
# 8   林煜清   41.0  5.27  1.68       15.1        4.11         1.63         12.1
# 9    喬登   37.2  5.97  1.65       10.2        2.53         1.59         17.1
# 10  張耿豪   36.1  5.20  1.65        8.2        3.12         1.50         15.1
# 11  郭泓志   34.0  3.71  1.32       11.2        2.31         1.11         11.0
# 12  陳仕朋   27.1  7.24  1.79       12.0        7.50         1.83          8.1
# 13  蔡明晉   26.0  6.92  1.81        8.0       12.38         2.62          5.1
# 14  吳世豪   22.0  1.64  1.14       11.0        3.27         1.18         11.0
# 15  林羿豪   20.0  4.05  1.15        6.0        1.50         1.00          5.2
# 16  羅嘉仁   18.1  8.35  2.18       11.0        9.00         2.00          4.0
# 17  林政賢   16.1  6.61  2.02        3.0        3.00         2.00          3.0
#
#     ERA_Brothers  WHIP_Brothers  IP_Lions  ERA_Lions  WHIP_Lions
# 0           2.28           0.96      47.2       4.34        1.39
# 1           2.30           1.31      68.1       3.95        1.11
# 2           4.98           1.52      28.2       5.97        1.60
# 3           5.60           1.53      29.2       4.55        1.62
# 4           2.00           1.22      19.1       3.26        1.40
# 5           3.47           1.16      12.2       8.53        2.45
# 6           6.30           1.90      17.1       6.23        1.15
# 7           4.05           1.27      15.1       1.76        0.91
# 8           2.19           1.05      13.1       9.45        2.33
# 9           6.23           1.44       9.2       9.31        2.07
# 10          4.11           1.30      12.1       8.03        2.19
# 11          2.45           1.09      11.1       6.35        1.76
# 12          6.48           1.68       7.0       7.71        1.86
# 13          8.44           2.06      12.2       2.84        1.18
# 14          0.00           1.09       0.0       0.00        0.00
# 15         11.12           1.94       8.1       1.08        0.72
# 16          2.25           2.25       3.1      13.50        2.70
# 17         15.00           2.00      10.1       5.23        2.03

# %%
fig = plt.figure(figsize=(25,10))
ax1 = fig.add_subplot(111)

for (i, row) in pitcher_inner.iterrows():
    plt.bar([i - 0.3, i - 0.1, i + 0.1, i + 0.3], [row['ERA'], row['ERA_Lamigo'], row['ERA_Brothers'], row['ERA_Lions']],
            color=['#888888', '#008AB8', '#FFD700', '#FF8C00'], width=0.2, align='center', edgecolor='#000000')

plt.xticks(range(0, 19), pitcher_inner['NAME'], fontsize=23)

#for x,y in enumerate(batter_inner['AVG']):
   #plt.text(x, y, '%1.3f' % y, ha='center', va= 'bottom',fontsize=11)


plt.xlabel('NAME')
plt.ylabel('ERA')
# Out:
# Text(0,0.5,'ERA')

# %%
fig = plt.figure(figsize=(25,10))
ax1 = fig.add_subplot(111)

for (i, row) in pitcher_inner.iterrows():
    plt.bar([i - 0.3, i - 0.1, i + 0.1, i + 0.3], [row['WHIP'], row['WHIP_Lamigo'], row['WHIP_Brothers'], row['WHIP_Lions']],
            color=['#888888', '#008AB8', '#FFD700', '#FF8C00'], width=0.2, align='center', edgecolor='#000000')

plt.xticks(range(0, 19), pitcher_inner['NAME'], fontsize=23)

#for x,y in enumerate(batter_inner['AVG']):
   #plt.text(x, y, '%1.3f' % y, ha='center', va= 'bottom',fontsize=11)


plt.xlabel('NAME')
plt.ylabel('WHIP')
# Out:
# Text(0,0.5,'WHIP')
